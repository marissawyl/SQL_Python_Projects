# %%
# Import libraries

import psycopg2
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create database connection

password = quote_plus('XXXX@XXXXX')

conn = create_engine(
    f'postgresql+psycopg2://postgres:{password}@localhost:5432/olist_db'
)

# %%
# Save query as string

query = '''
WITH delivered_orders AS (
	SELECT
		cohort_year,
		order_purchase_timestamp,
		is_reviewed
	FROM vw_order_customer
	WHERE
		is_approved = 1
		AND is_delivered = 1
),
agg AS (
	SELECT
		cohort_year,
		DATE_TRUNC('quarter', order_purchase_timestamp) AS order_quarter,
		COUNT(*) AS total_delivered_cnt,
		SUM(CASE WHEN is_reviewed = 0 THEN 1 ELSE 0 END) AS not_reviewed_cnt
	FROM delivered_orders
	GROUP BY 
		cohort_year,
		order_quarter
)

SELECT
	cohort_year,
	order_quarter,
	total_delivered_cnt,
	not_reviewed_cnt,
	ROUND((100 * not_reviewed_cnt::NUMERIC / total_delivered_cnt), 2) AS pct_vs_delivered_orders
FROM agg
ORDER BY
	cohort_year,
	order_quarter;
'''

# %%
# Execute SQL query and load into DataFrame
df = pd.read_sql(query, conn)

# Make sure cohort_year is treated as an integer for sorting and plotting
df['cohort_year'] = df['cohort_year'].astype('int')
# Convert order_quarter to a readable quarter label
df['quarter_label'] = df['order_quarter'].dt.to_period('Q').astype('str')

df
# Out:
#     cohort_year order_quarter  total_delivered_cnt  not_reviewed_cnt  \
# 0          2016    2016-07-01                    1                 0
# 1          2016    2016-10-01                  266                 3
# 2          2016    2017-01-01                    1                 0
# 3          2016    2017-04-01                    1                 0
# 4          2016    2017-07-01                    2                 0
# 5          2016    2017-10-01                    1                 0
# 6          2016    2018-01-01                    2                 0
# 7          2016    2018-04-01                    4                 0
# 8          2017    2017-01-01                 4934                38
# 9          2017    2017-04-01                 8983                65
# 10         2017    2017-07-01                12213                90
# 11         2017    2017-10-01                17279               135
# 12         2017    2018-01-01                  335                 8
# 13         2017    2018-04-01                  270                 3
# 14         2017    2018-07-01                  135                 1
# 15         2018    2018-01-01                20290               151
# 16         2018    2018-04-01                19372                94
# 17         2018    2018-07-01                12375                58
#
#     pct_vs_delivered_orders quarter_label
# 0                      0.00        2016Q3
# 1                      1.13        2016Q4
# 2                      0.00        2017Q1
# 3                      0.00        2017Q2
# 4                      0.00        2017Q3
# 5                      0.00        2017Q4
# 6                      0.00        2018Q1
# 7                      0.00        2018Q2
# 8                      0.77        2017Q1
# 9                      0.72        2017Q2
# 10                     0.74        2017Q3
# 11                     0.78        2017Q4
# 12                     2.39        2018Q1
# 13                     1.11        2018Q2
# 14                     0.74        2018Q3
# 15                     0.74        2018Q1
# 16                     0.49        2018Q2
# 17                     0.47        2018Q3

# %%
# Pivot table to show % of not-reviewed delivered orders by cohort and quarter
table = df.pivot_table(
    index='cohort_year',
    columns='quarter_label',
    values='pct_vs_delivered_orders',
    fill_value=0
)

# Hide text when there is no data (0 = no data, not 0%)
def annot_format(x):
    return "" if x == 0 else f"{x:.2f}%"

# Style the table for better readability
styled_table = (
    table.style
    # Green gradient to highlight higher percentages
    .background_gradient(
        cmap='Greens',
        vmin=0,
        vmax=3
    )
    # Apply custom text formatting
    .format(annot_format)
    # Table title
    .set_caption(
        "Share of Delivered Orders Not Reviewed by Cohort and Quarter "
        "(blank = no data)"
    )
)

styled_table
# Out:
# <style type="text/css">
# #T_ceaa3_row0_col0, #T_ceaa3_row0_col2, #T_ceaa3_row0_col3, #T_ceaa3_row0_col4, #T_ceaa3_row0_col5, #T_ceaa3_row0_col6, #T_ceaa3_row0_col7, #T_ceaa3_row0_col8, #T_ceaa3_row1_col0, #T_ceaa3_row1_col1, #T_ceaa3_row2_col0, #T_ceaa3_row2_col1, #T_ceaa3_row2_col2, #T_ceaa3_row2_col3, #T_ceaa3_row2_col4, #T_ceaa3_row2_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_ceaa3_row0_col1 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_ceaa3_row1_col2 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_ceaa3_row1_col3 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_ceaa3_row1_col4, #T_ceaa3_row1_col8, #T_ceaa3_row2_col6 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_ceaa3_row1_col5 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_ceaa3_row1_col6 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_ceaa3_row1_col7 {
#   background-color: #a3da9d;
#   color: #000000;
# }
# #T_ceaa3_row2_col7 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_ceaa3_row2_col8 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# </style>
# <table id="T_ceaa3">
#   <caption>Share of Delivered Orders Not Reviewed by Cohort and Quarter (blank = no data)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >quarter_label</th>
#       <th id="T_ceaa3_level0_col0" class="col_heading level0 col0" >2016Q3</th>
#       <th id="T_ceaa3_level0_col1" class="col_heading level0 col1" >2016Q4</th>
#       <th id="T_ceaa3_level0_col2" class="col_heading level0 col2" >2017Q1</th>
#       <th id="T_ceaa3_level0_col3" class="col_heading level0 col3" >2017Q2</th>
#       <th id="T_ceaa3_level0_col4" class="col_heading level0 col4" >2017Q3</th>
#       <th id="T_ceaa3_level0_col5" class="col_heading level0 col5" >2017Q4</th>
#       <th id="T_ceaa3_level0_col6" class="col_heading level0 col6" >2018Q1</th>
#       <th id="T_ceaa3_level0_col7" class="col_heading level0 col7" >2018Q2</th>
#       <th id="T_ceaa3_level0_col8" class="col_heading level0 col8" >2018Q3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cohort_year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceaa3_level0_row0" class="row_heading level0 row0" >2016</th>
#       <td id="T_ceaa3_row0_col0" class="data row0 col0" ></td>
#       <td id="T_ceaa3_row0_col1" class="data row0 col1" >1.13%</td>
#       <td id="T_ceaa3_row0_col2" class="data row0 col2" ></td>
#       <td id="T_ceaa3_row0_col3" class="data row0 col3" ></td>
#       <td id="T_ceaa3_row0_col4" class="data row0 col4" ></td>
#       <td id="T_ceaa3_row0_col5" class="data row0 col5" ></td>
#       <td id="T_ceaa3_row0_col6" class="data row0 col6" ></td>
#       <td id="T_ceaa3_row0_col7" class="data row0 col7" ></td>
#       <td id="T_ceaa3_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_ceaa3_level0_row1" class="row_heading level0 row1" >2017</th>
#       <td id="T_ceaa3_row1_col0" class="data row1 col0" ></td>
#       <td id="T_ceaa3_row1_col1" class="data row1 col1" ></td>
#       <td id="T_ceaa3_row1_col2" class="data row1 col2" >0.77%</td>
#       <td id="T_ceaa3_row1_col3" class="data row1 col3" >0.72%</td>
#       <td id="T_ceaa3_row1_col4" class="data row1 col4" >0.74%</td>
#       <td id="T_ceaa3_row1_col5" class="data row1 col5" >0.78%</td>
#       <td id="T_ceaa3_row1_col6" class="data row1 col6" >2.39%</td>
#       <td id="T_ceaa3_row1_col7" class="data row1 col7" >1.11%</td>
#       <td id="T_ceaa3_row1_col8" class="data row1 col8" >0.74%</td>
#     </tr>
#     <tr>
#       <th id="T_ceaa3_level0_row2" class="row_heading level0 row2" >2018</th>
#       <td id="T_ceaa3_row2_col0" class="data row2 col0" ></td>
#       <td id="T_ceaa3_row2_col1" class="data row2 col1" ></td>
#       <td id="T_ceaa3_row2_col2" class="data row2 col2" ></td>
#       <td id="T_ceaa3_row2_col3" class="data row2 col3" ></td>
#       <td id="T_ceaa3_row2_col4" class="data row2 col4" ></td>
#       <td id="T_ceaa3_row2_col5" class="data row2 col5" ></td>
#       <td id="T_ceaa3_row2_col6" class="data row2 col6" >0.74%</td>
#       <td id="T_ceaa3_row2_col7" class="data row2 col7" >0.49%</td>
#       <td id="T_ceaa3_row2_col8" class="data row2 col8" >0.47%</td>
#     </tr>
#   </tbody>
# </table>
