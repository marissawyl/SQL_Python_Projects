# %%
# Import libraries

import psycopg2
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create database connection

password = quote_plus('XXXX@XXXXX')

conn = create_engine(
    f'postgresql+psycopg2://postgres:{password}@localhost:5432/olist_db'
)

# %%
# Save query as string

query = '''
WITH order_base AS (
	SELECT
		DATE_TRUNC('quarter', order_purchase_timestamp) AS order_quarter,
		cohort_year,
		order_id,
		order_status,
		is_approved,
		is_delivered,
		is_reviewed
	FROM vw_order_customer
),
anomaly_types_count AS (
	SELECT
		cohort_year,
		order_quarter,
		anomaly_type,
		COUNT(order_id) AS order_cnt
	FROM  (
		SELECT
			cohort_year,
			order_quarter,
			order_id,
			CASE
				WHEN is_delivered = 1 AND is_approved = 0
					THEN 'delivered_not_approved'
				WHEN is_reviewed = 1 AND is_approved = 0
					THEN 'reviewed_not_approved'
				WHEN is_reviewed = 1 AND is_delivered = 0 THEN
					CASE
						WHEN order_status IN ('shipped', 'invoiced', 'processing', 'approved')
							THEN 'pipeline_latency'
						WHEN order_status IN ('canceled', 'created', 'unavailable')
							THEN 'review_before_delivery'
					END
			END AS anomaly_type
		FROM order_base
	) t
	WHERE anomaly_type IS NOT NULL
	GROUP BY
		cohort_year,
		order_quarter,
		anomaly_type
),
total_all_orders AS (
	SELECT
		cohort_year,
		order_quarter,
		COUNT(order_id) AS total_order_cnt
	FROM order_base
	GROUP BY
		cohort_year,
		order_quarter
),
total_related_orders AS (
	SELECT
		cohort_year,
		order_quarter,
		SUM(CASE WHEN is_delivered = 1 THEN 1 ELSE 0 END) AS total_delivered_cnt,
		SUM(CASE WHEN is_reviewed = 1 THEN 1 ELSE 0 END) AS total_reviewed_cnt
	FROM order_base
	GROUP BY
		cohort_year,
		order_quarter
)

SELECT
	ac.cohort_year,
	ac.order_quarter,
	ac.anomaly_type,
	ac.order_cnt,
	CASE
		WHEN ac.anomaly_type = 'delivered_not_approved' THEN ROUND((100 * ac.order_cnt::NUMERIC / NULLIF(tr.total_delivered_cnt, 0)), 2)
		ELSE ROUND((100 * ac.order_cnt::NUMERIC / NULLIF(tr.total_reviewed_cnt, 0)), 2)
	END AS pct_of_relevant_orders,
	ROUND((100 * ac.order_cnt::NUMERIC / ta.total_order_cnt), 2) AS pct_of_all_orders
FROM anomaly_types_count ac
JOIN total_related_orders tr
	ON ac.cohort_year = tr.cohort_year
	AND ac.order_quarter = tr.order_quarter
JOIN total_all_orders ta
	ON ac.cohort_year = ta.cohort_year
	AND ac.order_quarter = ta.order_quarter
ORDER BY
	ac.cohort_year,
	ac.order_quarter,
	ac.anomaly_type;
'''

# %%
# Execute SQL query and load into DataFrame
df = pd.read_sql(query, conn)

# Make sure cohort_year is treated as an integer for sorting and plotting
df['cohort_year'] = df['cohort_year'].astype('int')
# Convert order_quarter to a readable quarter label
df['quarter_label'] = df['order_quarter'].dt.to_period('Q').astype('str')

df
# Out:
#     cohort_year order_quarter            anomaly_type  order_cnt  \
# 0          2016    2016-07-01        pipeline_latency          1
# 1          2016    2016-07-01  review_before_delivery          2
# 2          2016    2016-10-01        pipeline_latency         26
# 3          2016    2016-10-01  review_before_delivery         25
# 4          2016    2016-10-01   reviewed_not_approved          6
# 5          2017    2017-01-01  delivered_not_approved         14
# 6          2017    2017-01-01        pipeline_latency        172
# 7          2017    2017-01-01  review_before_delivery        131
# 8          2017    2017-01-01   reviewed_not_approved          5
# 9          2017    2017-04-01        pipeline_latency        228
# 10         2017    2017-04-01  review_before_delivery        107
# 11         2017    2017-04-01   reviewed_not_approved         17
# 12         2017    2017-07-01        pipeline_latency        221
# 13         2017    2017-07-01  review_before_delivery        179
# 14         2017    2017-07-01   reviewed_not_approved         14
# 15         2017    2017-10-01        pipeline_latency        286
# 16         2017    2017-10-01  review_before_delivery        234
# 17         2017    2017-10-01   reviewed_not_approved         20
# 18         2017    2018-01-01        pipeline_latency          5
# 19         2017    2018-01-01  review_before_delivery          7
# 20         2017    2018-01-01   reviewed_not_approved          1
# 21         2017    2018-04-01  review_before_delivery          3
# 22         2017    2018-07-01        pipeline_latency          2
# 23         2017    2018-07-01  review_before_delivery          1
# 24         2018    2018-01-01        pipeline_latency        332
# 25         2018    2018-01-01  review_before_delivery        202
# 26         2018    2018-01-01   reviewed_not_approved          6
# 27         2018    2018-04-01        pipeline_latency        232
# 28         2018    2018-04-01  review_before_delivery         78
# 29         2018    2018-04-01   reviewed_not_approved          1
# 30         2018    2018-07-01        pipeline_latency        133
# 31         2018    2018-07-01  review_before_delivery         93
# 32         2018    2018-07-01   reviewed_not_approved         67
# 33         2018    2018-10-01   reviewed_not_approved          4
#
#     pct_of_relevant_orders  pct_of_all_orders quarter_label
# 0                    25.00              25.00        2016Q3
# 1                    50.00              50.00        2016Q3
# 2                     8.13               8.00        2016Q4
# 3                     7.81               7.69        2016Q4
# 4                     1.88               1.85        2016Q4
# 5                     0.28               0.27        2017Q1
# 6                     3.30               3.27        2017Q1
# 7                     2.51               2.49        2017Q1
# 8                     0.10               0.10        2017Q1
# 9                     2.46               2.44        2017Q2
# 10                    1.15               1.14        2017Q2
# 11                    0.18               0.18        2017Q2
# 12                    1.76               1.75        2017Q3
# 13                    1.43               1.42        2017Q3
# 14                    0.11               0.11        2017Q3
# 15                    1.62               1.60        2017Q4
# 16                    1.32               1.31        2017Q4
# 17                    0.11               0.11        2017Q4
# 18                    1.47               1.44        2018Q1
# 19                    2.06               2.01        2018Q1
# 20                    0.29               0.29        2018Q1
# 21                    1.11               1.10        2018Q2
# 22                    1.46               1.45        2018Q3
# 23                    0.73               0.72        2018Q3
# 24                    1.61               1.59        2018Q1
# 25                    0.98               0.97        2018Q1
# 26                    0.03               0.03        2018Q1
# 27                    1.18               1.18        2018Q2
# 28                    0.40               0.40        2018Q2
# 29                    0.01               0.01        2018Q2
# 30                    1.05               1.05        2018Q3
# 31                    0.74               0.73        2018Q3
# 32                    0.53               0.53        2018Q3
# 33                  100.00             100.00        2018Q4

# %%
# Create pivot table: rows = cohort & anomaly type, columns = quarter
table = df.pivot_table(
    index=['cohort_year', 'anomaly_type'],
    columns='quarter_label',
    values='pct_of_all_orders',
    fill_value=0
)

# Hide text for missing data (0 means no data, not 0%)
def annot_format(x):
    return "" if x == 0 else f"{x:.2f}%"

# Style the table for better readability
styled_table = (
    table.style
    # Blue gradient to highlight higher percentages
    .background_gradient(
        cmap='Blues',
        vmin=0,
        vmax=5
    )
    # Apply custom text formatting
    .format(annot_format)
    # Table title
    .set_caption("Anomaly Rate by Quarter per Cohort (blank = no data)")
)

styled_table
# Out:
# <style type="text/css">
# #T_409a2_row0_col0, #T_409a2_row0_col1, #T_409a2_row1_col0, #T_409a2_row1_col1, #T_409a2_row9_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_409a2_row0_col2, #T_409a2_row0_col3, #T_409a2_row0_col4, #T_409a2_row0_col5, #T_409a2_row0_col6, #T_409a2_row0_col7, #T_409a2_row0_col8, #T_409a2_row0_col9, #T_409a2_row1_col2, #T_409a2_row1_col3, #T_409a2_row1_col4, #T_409a2_row1_col5, #T_409a2_row1_col6, #T_409a2_row1_col7, #T_409a2_row1_col8, #T_409a2_row1_col9, #T_409a2_row2_col0, #T_409a2_row2_col2, #T_409a2_row2_col3, #T_409a2_row2_col4, #T_409a2_row2_col5, #T_409a2_row2_col6, #T_409a2_row2_col7, #T_409a2_row2_col8, #T_409a2_row2_col9, #T_409a2_row3_col0, #T_409a2_row3_col1, #T_409a2_row3_col3, #T_409a2_row3_col4, #T_409a2_row3_col5, #T_409a2_row3_col6, #T_409a2_row3_col7, #T_409a2_row3_col8, #T_409a2_row3_col9, #T_409a2_row4_col0, #T_409a2_row4_col1, #T_409a2_row4_col7, #T_409a2_row4_col9, #T_409a2_row5_col0, #T_409a2_row5_col1, #T_409a2_row5_col9, #T_409a2_row6_col0, #T_409a2_row6_col1, #T_409a2_row6_col7, #T_409a2_row6_col8, #T_409a2_row6_col9, #T_409a2_row7_col0, #T_409a2_row7_col1, #T_409a2_row7_col2, #T_409a2_row7_col3, #T_409a2_row7_col4, #T_409a2_row7_col5, #T_409a2_row7_col9, #T_409a2_row8_col0, #T_409a2_row8_col1, #T_409a2_row8_col2, #T_409a2_row8_col3, #T_409a2_row8_col4, #T_409a2_row8_col5, #T_409a2_row8_col9, #T_409a2_row9_col0, #T_409a2_row9_col1, #T_409a2_row9_col2, #T_409a2_row9_col3, #T_409a2_row9_col4, #T_409a2_row9_col5, #T_409a2_row9_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_409a2_row2_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_409a2_row3_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_409a2_row4_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_409a2_row4_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_409a2_row4_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_409a2_row4_col5, #T_409a2_row7_col6 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_409a2_row4_col6 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_409a2_row4_col8 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_409a2_row5_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_409a2_row5_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_409a2_row5_col4 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_409a2_row5_col5 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_409a2_row5_col6 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_409a2_row5_col7 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_409a2_row5_col8 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_409a2_row6_col2, #T_409a2_row6_col4, #T_409a2_row6_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_409a2_row6_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_409a2_row6_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_409a2_row7_col7 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_409a2_row7_col8 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_409a2_row8_col6 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_409a2_row8_col7 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_409a2_row8_col8 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_409a2_row9_col6 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_409a2_row9_col8 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# </style>
# <table id="T_409a2">
#   <caption>Anomaly Rate by Quarter per Cohort (blank = no data)</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >quarter_label</th>
#       <th id="T_409a2_level0_col0" class="col_heading level0 col0" >2016Q3</th>
#       <th id="T_409a2_level0_col1" class="col_heading level0 col1" >2016Q4</th>
#       <th id="T_409a2_level0_col2" class="col_heading level0 col2" >2017Q1</th>
#       <th id="T_409a2_level0_col3" class="col_heading level0 col3" >2017Q2</th>
#       <th id="T_409a2_level0_col4" class="col_heading level0 col4" >2017Q3</th>
#       <th id="T_409a2_level0_col5" class="col_heading level0 col5" >2017Q4</th>
#       <th id="T_409a2_level0_col6" class="col_heading level0 col6" >2018Q1</th>
#       <th id="T_409a2_level0_col7" class="col_heading level0 col7" >2018Q2</th>
#       <th id="T_409a2_level0_col8" class="col_heading level0 col8" >2018Q3</th>
#       <th id="T_409a2_level0_col9" class="col_heading level0 col9" >2018Q4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cohort_year</th>
#       <th class="index_name level1" >anomaly_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_409a2_level0_row0" class="row_heading level0 row0" rowspan="3">2016</th>
#       <th id="T_409a2_level1_row0" class="row_heading level1 row0" >pipeline_latency</th>
#       <td id="T_409a2_row0_col0" class="data row0 col0" >25.00%</td>
#       <td id="T_409a2_row0_col1" class="data row0 col1" >8.00%</td>
#       <td id="T_409a2_row0_col2" class="data row0 col2" ></td>
#       <td id="T_409a2_row0_col3" class="data row0 col3" ></td>
#       <td id="T_409a2_row0_col4" class="data row0 col4" ></td>
#       <td id="T_409a2_row0_col5" class="data row0 col5" ></td>
#       <td id="T_409a2_row0_col6" class="data row0 col6" ></td>
#       <td id="T_409a2_row0_col7" class="data row0 col7" ></td>
#       <td id="T_409a2_row0_col8" class="data row0 col8" ></td>
#       <td id="T_409a2_row0_col9" class="data row0 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_409a2_level1_row1" class="row_heading level1 row1" >review_before_delivery</th>
#       <td id="T_409a2_row1_col0" class="data row1 col0" >50.00%</td>
#       <td id="T_409a2_row1_col1" class="data row1 col1" >7.69%</td>
#       <td id="T_409a2_row1_col2" class="data row1 col2" ></td>
#       <td id="T_409a2_row1_col3" class="data row1 col3" ></td>
#       <td id="T_409a2_row1_col4" class="data row1 col4" ></td>
#       <td id="T_409a2_row1_col5" class="data row1 col5" ></td>
#       <td id="T_409a2_row1_col6" class="data row1 col6" ></td>
#       <td id="T_409a2_row1_col7" class="data row1 col7" ></td>
#       <td id="T_409a2_row1_col8" class="data row1 col8" ></td>
#       <td id="T_409a2_row1_col9" class="data row1 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_409a2_level1_row2" class="row_heading level1 row2" >reviewed_not_approved</th>
#       <td id="T_409a2_row2_col0" class="data row2 col0" ></td>
#       <td id="T_409a2_row2_col1" class="data row2 col1" >1.85%</td>
#       <td id="T_409a2_row2_col2" class="data row2 col2" ></td>
#       <td id="T_409a2_row2_col3" class="data row2 col3" ></td>
#       <td id="T_409a2_row2_col4" class="data row2 col4" ></td>
#       <td id="T_409a2_row2_col5" class="data row2 col5" ></td>
#       <td id="T_409a2_row2_col6" class="data row2 col6" ></td>
#       <td id="T_409a2_row2_col7" class="data row2 col7" ></td>
#       <td id="T_409a2_row2_col8" class="data row2 col8" ></td>
#       <td id="T_409a2_row2_col9" class="data row2 col9" ></td>
#     </tr>
#     <tr>
#       <th id="T_409a2_level0_row3" class="row_heading level0 row3" rowspan="4">2017</th>
#       <th id="T_409a2_level1_row3" class="row_heading level1 row3" >delivered_not_approved</th>
#       <td id="T_409a2_row3_col0" class="data row3 col0" ></td>
#       <td id="T_409a2_row3_col1" class="data row3 col1" ></td>
#       <td id="T_409a2_row3_col2" class="data row3 col2" >0.27%</td>
#       <td id="T_409a2_row3_col3" class="data row3 col3" ></td>
#       <td id="T_409a2_row3_col4" class="data row3 col4" ></td>
#       <td id="T_409a2_row3_col5" class="data row3 col5" ></td>
#       <td id="T_409a2_row3_col6" class="data row3 col6" ></td>
#       <td id="T_409a2_row3_col7" class="data ro
